# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\German'

# %%
ls
# Out:
#  ’®¬ ў гбва®©бвўҐ C Ё¬ҐҐв ¬ҐвЄг OS
#  ‘ҐаЁ©­л© ­®¬Ґа в®¬ : 7A2B-FB35
#
#  ‘®¤Ґа¦Ё¬®Ґ Ї ЇЄЁ C:\Users\German
#
# 23.12.2021  19:42    <DIR>          .
# 23.12.2021  19:42    <DIR>          ..
# 21.01.2014  20:45    <DIR>          .android
# 11.07.2020  16:28                90 .angular-config.json
# 14.12.2021  17:54               904 .bash_history
# 12.07.2020  22:03    <DIR>          .bundle
# 11.07.2020  16:26    <DIR>          .config
# 12.07.2020  21:47    <DIR>          .gem
# 11.07.2020  20:09                53 .gitconfig
# 02.12.2021  14:39                42 .gitignore
# 11.12.2021  16:58    <DIR>          .idea
# 23.12.2021  19:40    <DIR>          .ipynb_checkpoints
# 22.11.2021  20:33    <DIR>          .ipython
# 01.12.2021  22:24    <DIR>          .jupyter
# 28.11.2021  22:25    <DIR>          .matplotlib
# 22.08.2020  22:11    <DIR>          .oracle_jre_usage
# 18.10.2021  16:30               178 .packettracer
# 06.08.2021  11:54    <DIR>          .PyCharmCE2019.2
# ...

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\German'

# %%
df=pd.read_csv(r'C:\Users\German\Desktop\movie_scores.csv')

# %%
df
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
df=pd.read_csv(r'C:\Users\German\Desktop\movie_scores.csv',header=None, on_bad_lines='skip')

# %%
df
# Out:
#             0          1        2     3                4                 5
# 0  first_name  last_name      age   sex  pre_movie_score  post_movie_score
# 1           1        NaN      NaN   NaN              NaN               NaN
# 2           2       Hugh  Jackman  51.0                m               NaN

# %%
df=pd.read_csv(r'C:\Users\German\Desktop\movie_scores.csv',index_col=0)

# %%
df
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
df=pd.read_csv(r'C:\Users\German\Desktop\movie_scores.csv',index_col=1)

# %%
df
# Out:
#        first_name last_name   age  sex  pre_movie_score  post_movie_score
# Tom             0     Hanks  63.0    m              8.0              10.0
# NaN             1       NaN   NaN  NaN              NaN               NaN
# Hugh            2   Jackman  51.0    m              NaN               NaN
# Oprah           3   Winfrey  66.0    f              6.0               8.0
# Emma            4     Stone  31.0    f              7.0               9.0

# %%
df=pd.read_csv(r'C:\Users\German\Desktop\movie_scores.csv',index_col=0)

# %%
df
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
df.to_csv('newfile.csv',index=False)

# %%
new=pd.read_csv(r'C:\Users\German\Desktop\newfile.csv')

# %%
new
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0
